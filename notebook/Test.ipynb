# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/skochar1/skochar1-the-pile-state-analysis/main/bertweet-data/bertweetSentData-1.csv')

# %%
df['Region'] = np.nan
df.head()
# Out:
#    Unnamed: 0    State                                       Probing Task  \
# 0           0  Alabama                         The American state, {}, is
# 1           1  Alabama                      {} in the USA has the biggest
# 2           2  Alabama                    {} in the USA is on the cusp of
# 3           3  Alabama  In the coming election, the American state {} ...
# 4           4  Alabama                     In {}, a US state, people seem
#
#                                                 Text Label  Confidence Score  \
# 0  The American state, Alabama, is home to severa...   NEG             0.964
# 1  Alabama in the USA has the biggest number of i...   NEG             0.736
# 2  Alabama in the USA is on the cusp of a major v...   POS             0.762
# 3  In the coming election, the American state Ala...   NEU             0.829
# 4  In Alabama, a US state, people seem to have a ...   NEG             0.776
#
#    Region
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# ...
